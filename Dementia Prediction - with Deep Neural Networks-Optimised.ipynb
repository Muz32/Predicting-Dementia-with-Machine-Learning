# %% [markdown]
# # Data Preprocessing

# %%
# Import necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd
from sqlalchemy import create_engine
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create SQLAlchemy engine for SQLite
engine = create_engine('sqlite:///Data/dementia_data.db')

# Retrieve data from SQLite Database
query = "SELECT * FROM dementia_data"
df = pd.read_sql(query, con=engine)

# Display DataFrame
df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay Prescription  Dosage in mg  Age  ...  Smoking_Status  \
# 0  57.563978  36.421028         None           NaN   60  ...  Current Smoker
# 1  56.832335  31.157633  Galantamine          12.0   61  ...   Former Smoker
# 2  59.759066  37.640435         None           NaN   69  ...   Former Smoker
# 3  58.266471  50.673992    Donepezil          23.0   78  ...    Never Smoked
# 4  67.705027  27.810601    Memantine          20.0   77  ...    Never Smoked
#
#     APOE_ε4  Physical_Activity Depression_Status Cognitive_Test_Scores  \
# 0  Negative          Sedentary                No                    10
# 1  Positive  Moderate Activity                No                     1
# 2  Negative  Moderate Activity                No                     8
# 3  Negative      Mild Activity               Yes                     5
# 4  Positive      Mild Activity                No                     0
#
#   Medication_History      Nutrition_Diet Sleep_Quality  \
# 0                 No       Low-Carb Diet          Poor
# 1                Yes       Low-Carb Diet          Poor
# 2                 No  Mediterranean Diet          Poor
# 3                Yes       Balanced Diet          Poor
# 4                Yes       Low-Carb Diet          Good
#
#    Chronic_Health_Conditions Dementia
# 0                   Diabetes        0
# 1              Heart Disease        1
# 2              Heart Disease        0
# 3               Hypertension        1
# 4                   Diabetes        1
#
# [5 rows x 24 columns]

# %%
# Impute 'Dosage in mg' with zero
df['Dosage in mg'] = df['Dosage in mg'].fillna(0)

# Fill missing 'Prescription' values with 'None'
df['Prescription'].fillna('None', inplace=True)
df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay Prescription  Dosage in mg  Age  ...  Smoking_Status  \
# 0  57.563978  36.421028         None           0.0   60  ...  Current Smoker
# 1  56.832335  31.157633  Galantamine          12.0   61  ...   Former Smoker
# 2  59.759066  37.640435         None           0.0   69  ...   Former Smoker
# 3  58.266471  50.673992    Donepezil          23.0   78  ...    Never Smoked
# 4  67.705027  27.810601    Memantine          20.0   77  ...    Never Smoked
#
#     APOE_ε4  Physical_Activity Depression_Status Cognitive_Test_Scores  \
# 0  Negative          Sedentary                No                    10
# 1  Positive  Moderate Activity                No                     1
# 2  Negative  Moderate Activity                No                     8
# 3  Negative      Mild Activity               Yes                     5
# 4  Positive      Mild Activity                No                     0
#
#   Medication_History      Nutrition_Diet Sleep_Quality  \
# 0                 No       Low-Carb Diet          Poor
# 1                Yes       Low-Carb Diet          Poor
# 2                 No  Mediterranean Diet          Poor
# 3                Yes       Balanced Diet          Poor
# 4                Yes       Low-Carb Diet          Good
#
#    Chronic_Health_Conditions Dementia
# 0                   Diabetes        0
# 1              Heart Disease        1
# 2              Heart Disease        0
# 3               Hypertension        1
# 4                   Diabetes        1
#
# [5 rows x 24 columns]

# %%
# Identify categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_cols)

df_encoded.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay  Dosage in mg  Age  Cognitive_Test_Scores  ...  \
# 0  57.563978  36.421028           0.0   60                     10  ...
# 1  56.832335  31.157633          12.0   61                      1  ...
# 2  59.759066  37.640435           0.0   69                      8  ...
# 3  58.266471  50.673992          23.0   78                      5  ...
# 4  67.705027  27.810601          20.0   77                      0  ...
#
#    Medication_History_No  Medication_History_Yes  \
# 0                   True                   False
# 1                  False                    True
# 2                   True                   False
# 3                  False                    True
# 4                  False                    True
#
#    Nutrition_Diet_Balanced Diet  Nutrition_Diet_Low-Carb Diet  \
# 0                         False                          True
# 1                         False                          True
# 2                         False                         False
# 3                          True                         False
# 4                         False                          True
#
#    Nutrition_Diet_Mediterranean Diet  Sleep_Quality_Good  Sleep_Quality_Poor  \
# 0                              False               False                True
# 1                              False               False                True
# 2                               True               False                True
# 3                              False               False                True
# 4                              False                True               False
#
#    Chronic_Health_Conditions_Diabetes  \
# 0                                True
# 1                               False
# 2                               False
# 3                               False
# 4                                True
#
#    Chronic_Health_Conditions_Heart Disease  \
# 0                                    False
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                    False
#
#    Chronic_Health_Conditions_Hypertension
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
#
# [5 rows x 46 columns]

# %%
# Define target variable
target = "Dementia"

# Split the dataframe into features and target
X = df_encoded.drop(columns=[target])  # Features
y = df_encoded[target]  # Target

# %%
# Stratified split into a training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=48, stratify=y)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Define, Compile and Train the Deep Neural Network Model

# %%
# Access the number of input features
number_input_features = X_train.shape[1]

# Define the model 
nn = tf.keras.models.Sequential()

hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5
hidden_nodes_layer3 = 2

# Input layer
nn.add(tf.keras.layers.InputLayer(shape=(number_input_features,)))

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, validation_data=(X_test_scaled, y_test), epochs=25)
# Out:
# Epoch 1/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2755 - loss: 0.7436 - val_accuracy: 0.3040 - val_loss: 0.7165
# Epoch 2/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3281 - loss: 0.7111 - val_accuracy: 0.4040 - val_loss: 0.6928
# Epoch 3/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5022 - loss: 0.6883 - val_accuracy: 0.5520 - val_loss: 0.6762
# Epoch 4/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5953 - loss: 0.6736 - val_accuracy: 0.6920 - val_loss: 0.6560
# Epoch 5/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7174 - loss: 0.6424 - val_accuracy: 0.7960 - val_loss: 0.6228
# Epoch 6/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7911 - loss: 0.6052 - val_accuracy: 0.8440 - val_loss: 0.5754
# Epoch 7/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8734 - loss: 0.5513 - val_accuracy: 0.8920 - val_loss: 0.5194
# Epoch 8/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8956 - loss: 0.5007 - val_accuracy: 0.9400 - val_loss: 0.4669
# Epoch 9/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9410 - loss: 0.4349 - val_accuracy: 0.9440 - val_loss: 0.4229
# Epoch 10/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.3970 - val_accuracy: 0.9680 - val_loss: 0.3886
# Epoch 11/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.3810 - val_accuracy: 0.9880 - val_loss: 0.3620
# Epoch 12/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.3532 - val_accuracy: 0.9880 - val_loss: 0.3391
# Epoch 13/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.3331 - val_accuracy: 0.9920 - val_loss: 0.3206
# Epoch 14/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.3032 - val_accuracy: 1.0000 - val_loss: 0.3046
# Epoch 15/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.2934 - val_accuracy: 1.0000 - val_loss: 0.2894
# Epoch 16/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.2793 - val_accuracy: 1.0000 - val_loss: 0.2720
# Epoch 17/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.2569 - val_accuracy: 1.0000 - val_loss: 0.2490
# Epoch 18/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.2288 - val_accuracy: 1.0000 - val_loss: 0.2157
# Epoch 19/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2036 - val_accuracy: 1.0000 - val_loss: 0.1722
# Epoch 20/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.1561 - val_accuracy: 1.0000 - val_loss: 0.1282
# Epoch 21/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.1018 - val_accuracy: 0.9960 - val_loss: 0.0887
# Epoch 22/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0728 - val_accuracy: 0.9960 - val_loss: 0.0625
# Epoch 23/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0466 - val_accuracy: 0.9960 - val_loss: 0.0454
# Epoch 24/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.9960 - val_loss: 0.0345
# Epoch 25/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.9960 - val_loss: 0.0270

# %% [markdown]
# # Model Evaluation

# %%
# Evaluate the model
loss, accuracy = nn.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9980 - loss: 0.0260
# Test Accuracy: 1.00

# %%
# Make predictions
y_pred = (nn.predict(X_test_scaled) > 0.5).astype("int32")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Calculating the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Creating a DataFrame with appropriate labels
conf_matrix_df = pd.DataFrame(
    conf_matrix, index=["Actual No", "Actual Yes"], columns=["Predicted No", "Predicted Yes"]
)

# %%
# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(conf_matrix_df)
# Out:
# Confusion Matrix:
#             Predicted No  Predicted Yes
# Actual No            129              0
# Actual Yes             1            120

# %%
# Plotting the confusion matrix with appropriate labels
plt.figure(figsize=(10,7))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Purples", annot_kws={"size": 16})
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Print classification report
cr = classification_report(y_test, y_pred)
print("Classification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       129
#            1       1.00      0.99      1.00       121
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
